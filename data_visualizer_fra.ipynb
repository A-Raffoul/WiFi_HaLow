# %%
# Importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import plotly.graph_objects as go
from scenario import*
import plotly.express as px
from ipywidgets import interact, interactive, fixed, interact_manual
# Out:
# /var/folders/xl/w9r1w1ps1bscvq8ybsfntfqr0000gn/T/ipykernel_16116/1973112955.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# init commits
scenarios = []
def extract_scenarios_from_text_files(directory):
    for root, dirs, files in os.walk(directory):
        for dir in dirs:
            source_dir = os.path.join(root, dir)
            for file in os.listdir(source_dir):
                print(file)
                if file.endswith('.txt'):
                    file_path = os.path.join(source_dir, file)
                    try:
                        scenario = Scenario(file_path)
                        scenarios.append(scenario)
                    except Exception as e:
                        print(f"An error occurred while processing {file_path}: {e}")
                        continue
    return scenarios


def scenarios_to_dataframe(scenarios):
    data_dicts = [scenario.to_dict() for scenario in scenarios]
    return pd.DataFrame(data_dicts)

def plot_interactive(df):
    def update_plot(x, y):
        fig = px.scatter(df, x=x, y=y, title=f'{x} vs {y}', labels={x: x, y: y})
        fig.show()

    columns = df.columns
    interact(update_plot, x=columns, y=columns)

# Example usage
logs_directory = r'/Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs'
scenarios = extract_scenarios_from_text_files(logs_directory)
data_frame = scenarios_to_dataframe(scenarios)
print(data_frame)


if not data_frame.empty:
    plot_interactive(data_frame)
else:
    print("No data available for plotting.")
# Out:
# coaxial_txpwr13_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr13_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr14_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr14_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr15_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr15_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr12_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr12_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr18_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr18_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr10_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr10_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr17_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr17_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr16_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr16_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr11_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr11_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr19_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr19_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr4_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr4_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr3_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr3_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr2_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr2_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr5_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr5_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr7_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr7_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr0_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr0_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr8_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr8_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr20_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr20_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr9_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr9_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr1_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr1_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr6_1Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_1MHz/coaxial_txpwr6_1Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr12_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr12_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr15_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr15_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr14_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr14_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr13_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr13_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr11_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr11_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr19_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr19_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr16_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr16_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr17_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr17_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr18_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr18_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr10_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr10_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr20_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr20_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr9_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr9_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr8_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr8_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr7_1Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_1MHz/coaxial_txpwr7_1Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr3_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr3_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr4_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr4_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr5_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr5_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr2_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr2_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr8_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr8_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr0_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr0_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr7_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr7_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr6_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr6_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr1_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr1_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr9_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr9_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr20_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr20_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr14_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr14_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr13_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr13_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr12_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr12_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr15_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr15_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr17_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr17_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr10_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr10_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr18_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr18_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr19_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr19_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr11_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr11_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr16_2Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_2MHz/coaxial_txpwr16_2Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr6_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr6_2Mhz_70dBm.txt: could not convert string to float: 'None'
# coaxial_txpwr1_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr1_2Mhz_70dBm.txt: could not convert string to float: 'None'
# coaxial_txpwr20_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr20_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr9_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr9_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr8_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr8_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr0_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr0_2Mhz_70dBm.txt: could not convert string to float: 'None'
# coaxial_txpwr7_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr7_2Mhz_70dBm.txt: could not convert string to float: 'None'
# coaxial_txpwr5_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr5_2Mhz_70dBm.txt: could not convert string to float: 'None'
# coaxial_txpwr2_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr2_2Mhz_70dBm.txt: could not convert string to float: 'None'
# coaxial_txpwr3_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr3_2Mhz_70dBm.txt: could not convert string to float: 'None'
# coaxial_txpwr4_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr4_2Mhz_70dBm.txt: could not convert string to float: 'None'
# coaxial_txpwr19_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr19_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr11_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr11_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr16_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr16_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr17_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr17_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr10_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr10_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr18_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr18_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr12_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr12_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr15_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr15_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr14_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr14_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr13_2Mhz_70dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_70dBm_STA_2MHz/coaxial_txpwr13_2Mhz_70dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr17_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr17_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr18_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr18_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr10_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr10_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr11_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr11_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr19_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr19_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr16_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr16_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr14_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr14_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr13_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr13_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr12_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr12_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr15_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr15_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr0_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr0_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr8_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr8_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr7_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr7_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr6_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr6_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr9_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr9_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr20_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr20_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr1_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr1_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr3_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr3_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr4_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr4_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr5_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr5_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr2_1Mhz_50dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_50dBm_STA_1MHz/coaxial_txpwr2_1Mhz_50dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr7_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr7_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr8_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr8_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr0_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr0_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr1_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr1_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr20_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr20_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr9_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr9_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr6_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr6_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr4_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr4_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr3_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr3_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr2_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr2_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr5_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr5_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr10_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr10_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr18_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr18_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr17_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr17_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr16_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr16_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr19_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr19_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr11_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr11_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr13_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr13_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr14_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr14_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr15_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr15_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# coaxial_txpwr12_2Mhz_60dBm.txt
# An error occurred while processing /Users/francesco/Library/CloudStorage/OneDrive-epfl.ch/MA2/Semester Project/DATA/WiFi_HaLow/data/coaxial/logs/results_60dBm_STA_2MHz/coaxial_txpwr12_2Mhz_60dBm.txt: unsupported operand type(s) for -: 'int' and 'str'
# Empty DataFrame
# Columns: []
# Index: []
# No data available for plotting.

# %%
scenarios[0].to_dict()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 scenarios[0].to_dict()
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Assuming scenarios is already populated
Scenario_coaxial_1MHz = []
Scenario_coaxial_2MHz = []

for scenario in scenarios:
    if scenario.bandwidth == "1M":
        Scenario_coaxial_1MHz.append(scenario)
    elif scenario.bandwidth == "2M":
        Scenario_coaxial_2MHz.append(scenario)


# Extract and group data by MCS
mcs_1m_data = defaultdict(list)
mcs_2m_data = defaultdict(list)

for scenario in Scenario_coaxial_1MHz:
    mcs_1m_data[scenario.mcs].append(scenario.rx_iperf_bitrate)

for scenario in Scenario_coaxial_2MHz:
    mcs_2m_data[scenario.mcs].append(scenario.rx_iperf_bitrate)

# Calculate mean and spread for 1M data
mcs_1m = []
mean_1m = []
spread_1m = []

for mcs, data_rates in mcs_1m_data.items():
    mcs_1m.append(mcs)
    mean_1m.append(np.mean(data_rates))
    spread_1m.append(np.std(data_rates))  # Using standard deviation as the spread



# Calculate mean and spread for 2M data
mcs_2m = []
mean_2m = []
spread_2m = []

for mcs, data_rates in mcs_2m_data.items():
    mcs_2m.append(mcs)
    mean_2m.append(np.mean(data_rates))
    spread_2m.append(np.std(data_rates))  # Using standard deviation as the spread

# Create the plot
plt.figure(figsize=(10, 6))

# Plot 1MHz data with error bars
plt.errorbar(mcs_1m, mean_1m, yerr=spread_1m, fmt='o', color='blue', label='1 MHz Bandwidth')

# Plot 2MHz data with error bars
plt.errorbar(mcs_2m, mean_2m, yerr=spread_2m, fmt='o', color='red', label='2 MHz Bandwidth')

# Adding title and labels
plt.title('MCS vs Data Rate')
plt.xlabel('MCS')
plt.ylabel('Data Rate (Mbits/sec)')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 14
#      12     elif scenario.bandwidth == "2M":
#      13         Scenario_coaxial_2MHz.append(scenario)
# ---> 14 scenario = Scenario_coaxial_1MHz[0]
#      16 # Extract and group data by MCS
#      17 mcs_1m_data = defaultdict(list)
#
# IndexError: list index out of range
